# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import re


import pickle
from scipy.sparse import hstack, csr_matrix
import lightgbm as lgb

# %% [markdown]
# ### Checking

# %%
out = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/dataset/sample_test_out.csv')
print(out.shape)
out.head()
# Out:
# (100, 2)
#    sample_id      price
# 0     217392  62.080008
# 1     209156  17.189763
# 2     262333  96.501410
# 3     295979   5.652474
# 4      50604  23.794780

# %%
TEST_DF = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/dataset/test.csv')
TEST_DF.head()
# Out:
#    sample_id                                    catalog_content  \
# 0     100179  Item Name: Rani 14-Spice Eshamaya's Mango Chut...
# 1     245611  Item Name: Natural MILK TEA Flavoring extract ...
# 2     146263  Item Name: Honey Filled Hard Candy - Bulk Pack...
# 3      95658  Item Name: Vlasic Snack'mm's Kosher Dill 16 Oz...
# 4      36806  Item Name: McCormick Culinary Vanilla Extract,...
#
#                                           image_link
# 0  https://m.media-amazon.com/images/I/71hoAn78AW...
# 1  https://m.media-amazon.com/images/I/61ex8NHCIj...
# 2  https://m.media-amazon.com/images/I/61KCM61J8e...
# 3  https://m.media-amazon.com/images/I/51Ex6uOH7y...
# 4  https://m.media-amazon.com/images/I/71QYlrOMoS...

# %% [markdown]
# so now i make a copy of test.csv and put all those extra columns and generate predictions via my Lightgbm model & store it into my train_copy.csv then i create another dataframe with only sample_id and price from train_copy.csv and submit it

# %% [markdown]
# ## Starting with submission file

# %%
BASE_PATH = '/content/drive/MyDrive/Colab Notebooks/Price_Prediction/'
TEST_PATH = f'{BASE_PATH}dataset/test.csv'

# Load data
test_df = pd.read_csv(TEST_PATH)

test_processed = test_df.copy()

# %%
# helper functions to create structured columns from catalog_content

# --- Unit conversion map to standardize to Ounce ---
UNIT_CONVERSION_TO_OUNCE = {
    'ounce': 1,
    'oz': 1,
    'fl oz': 1,         # assuming fluid ounces are okay as is for this context
    'fluid ounce': 1,
    'pound': 16,
    'lb': 16,
    'lbs': 16,
    'gram': 0.035274,
    'g': 0.035274,
    'kg': 35.274,
    'ml': 0.033814,
    'l': 33.814,
}


def normalize_unit(raw_unit):
    if not raw_unit:
        return None
    unit = raw_unit.strip().lower().replace('.', '').rstrip('s')
    return UNIT_CONVERSION_TO_OUNCE.get(unit, None)


def extract_pack_count(item_name):
    if not isinstance(item_name, str):
        return 1
    # More robust patterns for pack/count mentions
    match = re.search(r'(\d+)\s*(?:per case|count|pk|pack|box|ct|bars?)', item_name, re.IGNORECASE)
    if not match:
        match = re.search(r'pack(?:\s+of)?\s*(\d+)', item_name, re.IGNORECASE)
    return int(match.group(1)) if match else 1


# def extract_unit_size(value, unit):
#     factor = normalize_unit(unit)
#     if factor is None or value is None:
#         return None
#     return round(value * factor, 2)


def extract_brand(item_name):
    if not isinstance(item_name, str) or not item_name.strip():
        return None
    return item_name.split()[0].strip("',.:")

# %%
#Extracting required features from catalog_content

def extract_value_unit_from_catalog(catalog_content):
    """
    Try to extract 'value' and 'unit' from text.
    If 'Unit' is 'Count', fallback to finding actual size (e.g. '12.7 oz', '8 L', etc.) in item name or bullets.
    """
    if not isinstance(catalog_content, str):
        return None, None

    value = None
    unit = None

    # Check for explicit Value: and Unit:
    # Step 1 — Parse explicit Value/Unit fields if present
    lines = catalog_content.split('\n')
    for line in lines:
        val_match = re.search(r'Value:\s*([\d\.]+)', line, re.IGNORECASE)
        if val_match:
            value = float(val_match.group(1))
        unit_match = re.search(r'Unit:\s*([\w\s\.]+)', line, re.IGNORECASE)
        if unit_match:
            unit = unit_match.group(1).strip()

    # Step 2 — If 'Unit' is Count or missing, fallback to physical quantity
    # Step 2: fallback to physical units if Unit is Count or missing
    if unit is None or (isinstance(unit, str) and unit.lower().startswith("count")):
        match = re.search(
            r'(\d+(?:\.\d+)?)\s*(ounce|oz|fl\s*oz|fluid\s*ounce|ml|l|gram|g|kg|pound|lb|lbs)',
            catalog_content, re.IGNORECASE
        )
        if match:
            value = float(match.group(1))
            unit = match.group(2).strip().lower().replace('.', '')

    return value, unit

def extract_item_name_from_catalog(catalog_content):
    if not isinstance(catalog_content, str):
        return None
    match = re.search(r'Item Name:\s*(.+)', catalog_content)
    if match:
        return match.group(1).strip()
    return None

def extract_features_from_catalog(catalog_content):
    item_name = extract_item_name_from_catalog(catalog_content)
    value, unit = extract_value_unit_from_catalog(catalog_content)

    brand_name = extract_brand(item_name)
    pack_count = extract_pack_count(item_name)
    unit_size = None
    # standardized_unit = None
    total_size = None

    # If physical unit exists
    if value is not None and unit is not None:
        factor = normalize_unit(unit)
        if factor:
            total_size_in_oz = value * factor

            # Detect if item name specifies per-pack size to avoid double counting
            match_name_size = None
            if isinstance(item_name, str):
                match_name_size = re.search(
                    r'(\d+(?:\.\d+)?)\s*(ounce|oz|ml|g|kg|lb|lbs)',
                    item_name, re.IGNORECASE
                )
            if match_name_size:
                name_val = float(match_name_size.group(1))
                name_unit = match_name_size.group(2).lower()
                name_factor = normalize_unit(name_unit)
                if name_factor:
                    name_val_oz = name_val * name_factor
                    # If name_val_oz * pack_count ≈ total_size_in_oz, treat it as per-unit size
                    if abs(name_val_oz * pack_count - total_size_in_oz) < 1e-3:
                        unit_size = round(name_val_oz, 2)
                        total_size = round(total_size_in_oz, 2)
                    else:
                        unit_size = round(total_size_in_oz, 2)
                        total_size = round(total_size_in_oz * pack_count, 2)
            else:
                unit_size = round(total_size_in_oz, 2)
                total_size = round(total_size_in_oz * pack_count, 2)

            # standardized_unit = "Ounce"

    return pd.Series({
        "brand_name": brand_name,
        "unit_size": unit_size,
        "pack_count": pack_count,
        # "standardized_unit": standardized_unit,
        "total_size": total_size
    })

def add_extracted_features(df_processed):
    """
    Given a DataFrame with a 'catalog_content' column,
    extract features and add new columns in place for the entire DataFrame.
    Safely extract features for all rows, handling None or missing catalog_content.
    """
    df_processed['catalog_content'] = df_processed['catalog_content'].fillna('')
    features_df = df_processed['catalog_content'].apply(extract_features_from_catalog)
    # Concatenate the new columns to the original dataframe
    df_processed = pd.concat([df_processed, features_df], axis=1)
    return df_processed

# %%
# Usage example
test_processed = add_extracted_features(test_processed)


directory = '/content/drive/MyDrive/Colab Notebooks/Price_Prediction/'  # Adjust this path to your desired directory
file_name = 'test_with_numerical_cols.csv'
file_path = directory + file_name

# Save df_processed to CSV
test_processed.to_csv(file_path, index=False)

test_processed.head()
# Out:
#    sample_id                                    catalog_content  \
# 0     100179  Item Name: Rani 14-Spice Eshamaya's Mango Chut...
# 1     245611  Item Name: Natural MILK TEA Flavoring extract ...
# 2     146263  Item Name: Honey Filled Hard Candy - Bulk Pack...
# 3      95658  Item Name: Vlasic Snack'mm's Kosher Dill 16 Oz...
# 4      36806  Item Name: McCormick Culinary Vanilla Extract,...
#
#                                           image_link brand_name  unit_size  \
# 0  https://m.media-amazon.com/images/I/71hoAn78AW...       Rani       10.5
# 1  https://m.media-amazon.com/images/I/61ex8NHCIj...    Natural        2.0
# 2  https://m.media-amazon.com/images/I/61KCM61J8e...      Honey       32.0
# 3  https://m.media-amazon.com/images/I/51Ex6uOH7y...     Vlasic       16.0
# 4  https://m.media-amazon.com/images/I/71QYlrOMoS...  McCormick       32.0
#
#    pack_count  total_size
# 0         1.0        10.5
# 1         1.0         2.0
# 2         2.0        64.0
# 3         2.0        32.0
# 4         1.0        32.0

# %%
#For testing

# -------------------
# Load test data (original test CSV)
# -------------------
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/test_with_numerical_cols.csv')

# -------------------
# Preprocess numeric features
# -------------------
num_cols = ['unit_size', 'pack_count', 'total_size']

# Make sure numeric columns exist; fill missing if needed
for col in num_cols:
    if col not in df_test.columns:
        df_test[col] = 0

X_num = np.log1p(df_test[num_cols].fillna(0))

# Load saved scaler from training
with open('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/numeric_scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

X_num_scaled = scaler.transform(X_num)
X_num_sparse = csr_matrix(X_num_scaled)

# -------------------
# Preprocess text features
# -------------------
with open('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/tfidf_vectorizer.pkl', 'rb') as f:
    tfidf = pickle.load(f)

X_text = tfidf.transform(df_test['catalog_content'].fillna(''))

# -------------------
# Combine numeric + text features
# -------------------
X_test = hstack([X_text, X_num_sparse]).tocsr()

# -------------------
# Load trained LightGBM model
# -------------------
lgb_model = lgb.Booster(model_file='/content/drive/MyDrive/Colab Notebooks/Price_Prediction/lgb_text_numeric.txt')

# -------------------
# Predict
# -------------------
y_pred_log = lgb_model.predict(X_test, num_iteration=lgb_model.best_iteration)
y_pred = np.expm1(y_pred_log)           # revert log scale
y_pred = np.maximum(y_pred, 0.01)       # ensure positive prices

# %%
# -------------------
# Prepare submission CSV
# -------------------
submission = pd.DataFrame({
    'sample_id': df_test['sample_id'],
    'price': y_pred
})

submission.to_csv('/content/drive/MyDrive/Colab Notebooks/Price_Prediction/submission.csv', index=False)

print("Submission CSV generated successfully!")
# Out:
# Submission CSV generated successfully!

# %%
# Out:
#    sample_id      price
# 0     100179  13.974093
# 1     245611  12.876577
# 2     146263  14.963148
# 3      95658   9.342249
# 4      36806  40.677516
